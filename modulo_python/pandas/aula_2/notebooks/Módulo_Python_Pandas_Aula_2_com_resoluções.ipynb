# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelpyc/harve/blob/main/modulo_python/pandas/aula_2/notebooks/M%C3%B3dulo_Python_Pandas_Aula_2_com_resolu%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Módulo Python - Pandas** 🐼
#
# ##**Aula 2**
#
#  Manipular as funções da biblioteca pandas do Pythton, compreendo as suas funcionalidades:
#  - [Inspeção de conteúdo](#inspecao-conteudo)
#  - [Atribuição de dados](#atribuicao-dados)
#  - [Filtros](#filtros)
#  - [Filtros AND e OR](#filtros-and-or)
#  - [Dados faltantes e duplicados](#dados-faltantes-e-duplicados)
# <br>
#
#  *Material elaborado por Rafael Nunes de Campos*

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# #Inspeção de conteúdo
# <a name="inspecao-conteudo"></a>

# %% [markdown]
# Nesta etapa, vamos aprender algumas formas simples de inspecionar o conteúdo de um DataFrame.

# %% [markdown]
# A função `describe()` retorna **estatísticas descritivas das colunas numéricas**, como média, valor mínimo, valor máximo e quartis.
#
#
# ```python
# df.describe()
# ```

# %% [markdown]
# A função `value_counts` quando usada em uma coluna, **retorna os valores únicos dessa coluna e a quantidade de vezes que cada valor aparece**.
#
# ```python
# df[coluna].value_counts()
# ```

# %% [markdown]
# ##Descoberta guiada
# *Inspeção de conteúdo*

# %% [markdown]
# Acesse o dataset do Titanic (https://www.harve.com.br/praticas/titanic-pt-BR.csv) e obtenha estatísticas sobre os passageiros:
#
# 1. Qual foi a idade média dos passageiros?
# 2. Quantas mulheres e quantos homens estavam a bordo?

# %%
df = pd.read_csv('https://www.harve.com.br/praticas/titanic-pt-BR.csv')
df.head()
# Out:
#    Id do passageiro  Sobrevivente  Classe  \
# 0                 1             0       3
# 1                 2             1       1
# 2                 3             1       3
# 3                 4             1       1
# 4                 5             0       3
#
#                                                 Nome       Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    Irmaos ou conjuge  Pais ou filhos            Ticket Tarifa do passageiro  \
# 0                  1               0         A/5 21171                 7.25
# 1                  1               0          PC 17599              712.833
# ...

# %%
# 1. Qual foi a idade média dos passageiros?

df.describe()
# Out:
#        Id do passageiro  Sobrevivente      Classe       Idade  \
# count        891.000000    891.000000  891.000000  714.000000
# mean         446.000000      0.383838    2.308642   29.699118
# std          257.353842      0.486592    0.836071   14.526497
# min            1.000000      0.000000    1.000000    0.420000
# 25%          223.500000      0.000000    2.000000   20.125000
# 50%          446.000000      0.000000    3.000000   28.000000
# 75%          668.500000      1.000000    3.000000   38.000000
# max          891.000000      1.000000    3.000000   80.000000
#
#        Irmaos ou conjuge  Pais ou filhos
# count         891.000000      891.000000
# mean            0.523008        0.381594
# std             1.102743        0.806057
# min             0.000000        0.000000
# 25%             0.000000        0.000000
# 50%             0.000000        0.000000
# 75%             1.000000        0.000000
# max             8.000000        6.000000

# %%
# 2. Quantas mulheres e quantos homens estavam a bordo?

df['Sexo'].value_counts()
# df['Sexo'].value_counts(normalize=True) * 100
# Out:
# Sexo
# masculino    577
# feminino     314
# Name: count, dtype: int64

# %% [markdown]
# ##Hands on!
# *Inspeção de conteúdo*

# %% [markdown]
# Ainda sobre o dataset do Titanic (https://www.harve.com.br/praticas/titanic-pt-BR.csv), obtenha agora as seguintes informações:
#
# 1. Qual foi porcentagem de sobreviventes?
# 2. Quais foram as classes utilizadas pelos passageiros do titanic e quantas pessoas utilizaram cada uma delas?

# %%
df = pd.read_csv('https://www.harve.com.br/praticas/titanic-pt-BR.csv')
df.head()
# Out:
#    Id do passageiro  Sobrevivente  Classe  \
# 0                 1             0       3
# 1                 2             1       1
# 2                 3             1       3
# 3                 4             1       1
# 4                 5             0       3
#
#                                                 Nome       Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    Irmaos ou conjuge  Pais ou filhos            Ticket Tarifa do passageiro  \
# 0                  1               0         A/5 21171                 7.25
# 1                  1               0          PC 17599              712.833
# ...

# %%
# 1. Qual foi porcentagem de sobreviventes?

df['Sobrevivente'].value_counts(normalize=True) * 100
# Out:
# Sobrevivente
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
# 2. Quais foram as classes utilizadas pelos passageiros do titanic e quantas pessoas utilizaram cada uma delas?

df['Classe'].value_counts()
# Out:
# Classe
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# # Atribuição de dados
# <a name="atribuicao-dados"></a>

# %% [markdown]
# Nesta etapa, vamos aprender como acessar, alterar e criar informações dentro de um DataFrame.

# %% [markdown]
# Um DataFrame é parecido com uma planilha excel: temos linhas, colunas e valores.

# %% [markdown]
# Para **acessar uma coluna**, podemos chamar diretamente pelo nome da coluna:
#
# ```python
# df['prova_1']
# ```

# %% [markdown]
# Para **acessar um valor** podemos usar a função `loc` com o **nome do índice** e o **nome da coluna**:
# ```python
# df.loc['Ana', 'prova_1']
# ```
# ou, usar a função `iloc` com a **posição da linha** e a **posição da coluna**:
# ```python
# df.iloc[0, 2]
# ```

# %% [markdown]
# <font size="5">Para **alterar um valor específico** do DataFrame, **use `loc`**!</font>
#
# O `loc` deixa claro **qual linha** e **qual coluna** devem ser alteradas.
# ```python
# df.loc['Ana', 'prova_1'] = 8
# ```
#
# Evite fazer alterações usando dois acessos seguidos, como:
#
# ```python
# df['Ana']['prova_1'] = 8
# ```
# *Esse tipo de escrita pode gerar alertas no pandas e nem sempre altera o DataFrame original corretamente!*

# %% [markdown]
# Para **criar uma nova coluna**, atribua o resultado diretamente ao nome da nova coluna:
# ```python
# df['media'] = (df['prova_1'] + df['prova_2']) / 2
# ```

# %% [markdown]
# ## Descoberta guiada
# *Atribuição de dados*

# %% [markdown]
# A partir do DataFrame de provas, vamos explorar as seguintes questões:
#
# 1. Selecione apenas a coluna `prova_1`
# 2. Consulte a nota da Ana na `prova_1`
# 3. Consulte o valor que está na quinta linha e na segunda coluna
# 4. Selecione as notas da `prova_1` de Carla, Silvio e Teresa
# 5. Selecione as linhas de Carla até Teresa, apenas para a coluna `prova_1`.
# 6. Selecione as duas últimas linhas da coluna `prova_2`
# 7. Altere a nota da Ana na `prova_1` para `8`.
# 8. Altere a nota da quarta linha e na `prova_1` para `0`.
# 9. Crie uma coluna chamada `media`, com a média entre `prova_1` e `prova_2`.

# %%
dados: dict = {
    'nome': ['Ana', 'Pedro', 'João', 'Carla', 'Silvio', 'Teresa', 'Claudia', 'Cristiane'],
    'prova_1': [6, 7, 8, 8, 9, 3, 6, 5],
    'prova_2': [7, 8, 5, 7, 10, 8, 7, 7],
    'turma': ['A', 'A', 'B', 'B', 'A', 'B', 'B', 'A']
}

df = pd.DataFrame(dados)
df
# Out:
#         nome  prova_1  prova_2 turma
# 0        Ana        6        7     A
# 1      Pedro        7        8     A
# 2       João        8        5     B
# 3      Carla        8        7     B
# 4     Silvio        9       10     A
# 5     Teresa        3        8     B
# 6    Claudia        6        7     B
# 7  Cristiane        5        7     A

# %%
# 1. Selecione apenas a coluna `prova_1`

df['prova_1']
# Out:
# 0    6
# 1    7
# 2    8
# 3    8
# 4    9
# 5    3
# 6    6
# 7    5
# Name: prova_1, dtype: int64

# %%
# 2. Consulte a nota da Ana na `prova_1`

df = df.set_index('nome')
df.loc['Ana', 'prova_1']
# Out:
# np.int64(6)

# %%
# 3. Consulte o valor que está na quinta linha e na segunda coluna

df.iloc[0, 0]
# Out:
# np.int64(6)

# %%
# 4. Selecione as notas da `prova_1` de Carla, Silvio e Teresa

df.loc[['Carla', 'Silvio', 'Teresa'], 'prova_1']
# Out:
# nome
# Carla     8
# Silvio    9
# Teresa    3
# Name: prova_1, dtype: int64

# %%
# 5. Selecione as linhas de Carla até Teresa, apenas para a coluna `prova_1`.

df.loc['Carla':'Teresa', 'prova_1']
# Out:
# nome
# Carla     8
# Silvio    9
# Teresa    3
# Name: prova_1, dtype: int64

# %%
# 6. Selecione as duas últimas linhas da coluna `prova_2`

df.iloc[-2:, 1]
# Out:
# nome
# Claudia      7
# Cristiane    7
# Name: prova_2, dtype: int64

# %%
# 7. Altere a nota da Ana na `prova_1` para `8`.

df.loc['Ana', 'prova_1'] = 8
df
# Out:
#            prova_1  prova_2 turma
# nome
# Ana              8        7     A
# Pedro            7        8     A
# João             8        5     B
# Carla            8        7     B
# Silvio           9       10     A
# Teresa           3        8     B
# Claudia          6        7     B
# Cristiane        5        7     A

# %%
# 8. Altere a nota da quarta linha e na `prova_1` para `0`.

df.iloc[3, 0] = 0
df
# Out:
#            prova_1  prova_2 turma
# nome
# Ana              8        7     A
# Pedro            7        8     A
# João             8        5     B
# Carla            0        7     B
# Silvio           9       10     A
# Teresa           3        8     B
# Claudia          6        7     B
# Cristiane        5        7     A

# %%
# 9. Crie uma coluna chamada `media`, com a média entre `prova_1` e `prova_2`.

df['media'] = (df['prova_1'] + df['prova_2']) / 2
df.reset_index()
# Out:
#         nome  prova_1  prova_2 turma  media
# 0        Ana        8        7     A    7.5
# 1      Pedro        7        8     A    7.5
# 2       João        8        5     B    6.5
# 3      Carla        0        7     B    3.5
# 4     Silvio        9       10     A    9.5
# 5     Teresa        3        8     B    5.5
# 6    Claudia        6        7     B    6.5
# 7  Cristiane        5        7     A    6.0

# %%
# df = df.set_index('nome')
df
# Out:
#            prova_1  prova_2 turma  media
# nome
# Ana              8        7     A    7.5
# Pedro            7        8     A    7.5
# João             8        5     B    6.5
# Carla            0        7     B    3.5
# Silvio           9       10     A    9.5
# Teresa           3        8     B    5.5
# Claudia          6        7     B    6.5
# Cristiane        5        7     A    6.0

# %% [markdown]
# ## Hands on!
# *Atribuição de dados*

# %% [markdown]
# Ainda sobre o dataset de provas, resolva:
#
# 1. Qual foi a nota do Pedro na `prova_2`?
# 2. Qual o valor está na linha de posição `2` e coluna de posição `1`?
# 3. Selecione as linhas de Pedro até Silvio, apenas para as colunas `prova_1` e `prova_2`
# 4. Altere o valor da `prova_2` de Silvio
# 5. Crie uma coluna chamada `media_ponderada`, contendo a média das provas onde a `prova_1` tem peso 2 e `prova_2` tem peso 3

# %%
dados: dict = {
    'nome': ['Ana', 'Pedro', 'João', 'Carla', 'Silvio', 'Teresa', 'Claudia', 'Cristiane'],
    'prova_1': [6, 7, 8, 8, 9, 3, 6, 5],
    'prova_2': [7, 8, 5, 7, 10, 8, 7, 7],
    'turma': ['A', 'A', 'B', 'B', 'A', 'B', 'B', 'A']
}

df = pd.DataFrame(dados)
df
# Out:
#         nome  prova_1  prova_2 turma
# 0        Ana        6        7     A
# 1      Pedro        7        8     A
# 2       João        8        5     B
# 3      Carla        8        7     B
# 4     Silvio        9       10     A
# 5     Teresa        3        8     B
# 6    Claudia        6        7     B
# 7  Cristiane        5        7     A

# %%
# 1. Qual foi a nota do Pedro na `prova_2`?

df.loc[df['nome'] == 'Pedro', 'prova_2']
# Out:
# 1    8
# Name: prova_2, dtype: int64

# %%
# 2. Qual o valor está na linha de posição `2` e coluna de posição `1`?

df.iloc[2, 1]
# Out:
# np.int64(8)

# %%
# 3. Selecione as linhas de Pedro até Silvio, apenas para as colunas `prova_1` e `prova_2`

df.loc['Pedro':'Silvio', ['prova_1', 'prova_2']]
# Out:
# Empty DataFrame
# Columns: [prova_1, prova_2]
# Index: []

# %%
# 4. Altere o valor da `prova_2` de Silvio

df.loc[df['nome'] == 'Silvio', 'prova_2'] = 10
df
# Out:
#         nome  prova_1  prova_2 turma
# 0        Ana        6        7     A
# 1      Pedro        7        8     A
# 2       João        8        5     B
# 3      Carla        8        7     B
# 4     Silvio        9       10     A
# 5     Teresa        3        8     B
# 6    Claudia        6        7     B
# 7  Cristiane        5        7     A

# %%
# 5. Crie uma coluna chamada `media_ponderada`, contendo a média das provas onde a `prova_1` tem peso 2 e `prova_2` tem peso 3

df['media_ponderada'] = (df['prova_1'] * 2 + df['prova_2'] * 3) / 5
df
# Out:
#         nome  prova_1  prova_2 turma  media_ponderada
# 0        Ana        6        7     A              6.6
# 1      Pedro        7        8     A              7.6
# 2       João        8        5     B              6.2
# 3      Carla        8        7     B              7.4
# 4     Silvio        9       10     A              9.6
# 5     Teresa        3        8     B              6.0
# 6    Claudia        6        7     B              6.6
# 7  Cristiane        5        7     A              6.2

# %% [markdown]
# #Filtros
# <a name="filtros"></a>

# %% [markdown]
# Filtros são usados para **selecionar apenas as linhas que atendem a uma condição**.
#
# Ao comparar uma coluna com algum valor, o pandas retorna `True` para as linhas que atendem à condição e `False` para as demais.
#
# ```python
# df['turma'] == 'A'
# ```

# %% [markdown]
# Essa condição pode ser atribuída a uma variável como uma máscara ou filtro:
#
# ```
# filtro = df['turma'] == 'A'
# ```

# %% [markdown]
# Depois, podemos aplicar o filtro dentro do DataFrame:
#
# ```
# df[filtro]
# ```
#
# Ou escrever o filtro direto no Dataframe:
# ```
# df[df['turma'] == 'A']
# ```

# %% [markdown]
# Os operadores do python são:
#
# * `==`   igual
# * `!=`   diferente
# * `>`    maior
# * `>=`   maior ou igual
# * `<`    menor
# * `<=`   menor ou igual

# %% [markdown]
# ## Descoberta guiada
# *Filtros*

# %% [markdown]
# Usando o DataFrame de notas, responda:
#
# 1. Crie um filtro para identificar quais alunos são da turma `A`.
# 2. Selecione os alunos com nota maior ou igual a `7` na `prova_1`.
# 3. Verifique a média da `prova_1` e veja quais alunos estão abaixo da média.

# %%
dados = {
    'nome': ['Ana', 'Pedro', 'João', 'Carla', 'Silvio', 'Teresa', 'Claudia', 'Cristiane'],
    'prova_1': [6, 7, 8, 8, 9, 3, 6, 5],
    'prova_2': [7, 8, 5, 7, 10, 8, 7, 7],
    'turma': ['A', 'A', 'B', 'B', 'A', 'B', 'B', 'A']
}

df = pd.DataFrame(dados)
df
# Out:
#         nome  prova_1  prova_2 turma
# 0        Ana        6        7     A
# 1      Pedro        7        8     A
# 2       João        8        5     B
# 3      Carla        8        7     B
# 4     Silvio        9       10     A
# 5     Teresa        3        8     B
# 6    Claudia        6        7     B
# 7  Cristiane        5        7     A

# %%
# 1. Crie um filtro para identificar quais alunos são da turma `A`.

filtro = df['turma'] == 'A'
df[filtro]
# Out:
#         nome  prova_1  prova_2 turma
# 0        Ana        6        7     A
# 1      Pedro        7        8     A
# 4     Silvio        9       10     A
# 7  Cristiane        5        7     A

# %%
# 2. Selecione os alunos com nota maior ou igual a `7` na `prova_1`.

df[df['prova_1'] >= 7]
# Out:
#      nome  prova_1  prova_2 turma
# 1   Pedro        7        8     A
# 2    João        8        5     B
# 3   Carla        8        7     B
# 4  Silvio        9       10     A

# %%
# 3. Verifique a média da `prova_1` e veja quais alunos estão abaixo da média.

df.describe()
# Out:
#         prova_1    prova_2
# count  8.000000   8.000000
# mean   6.500000   7.375000
# std    1.927248   1.407886
# min    3.000000   5.000000
# 25%    5.750000   7.000000
# 50%    6.500000   7.000000
# 75%    8.000000   8.000000
# max    9.000000  10.000000

# %%
media = df.describe().loc['mean', 'prova_1']
df['nome'].loc[df['prova_1'] < media]
# Out:
# 0          Ana
# 5       Teresa
# 6      Claudia
# 7    Cristiane
# Name: nome, dtype: object

# %% [markdown]
# ## Hands on!
# *Filtros*

# %% [markdown]
# Vamos voltar ao dataset do titanic e resolver:
#
# 1. Selecione somente os passageiros da classe `1`.
# 2. Selecione somente os passageiros com idade maior ou igual a `30`.
# 3. Descreva quais os Locais de Embarque mais tiveram sobreviventes.
# 4. Mostre as estatíticas dos passageiros que não sobreviveram.

# %%
df = pd.read_csv('https://www.harve.com.br/praticas/titanic-pt-BR.csv')
df.head()
# Out:
#    Id do passageiro  Sobrevivente  Classe  \
# 0                 1             0       3
# 1                 2             1       1
# 2                 3             1       3
# 3                 4             1       1
# 4                 5             0       3
#
#                                                 Nome       Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    Irmaos ou conjuge  Pais ou filhos            Ticket Tarifa do passageiro  \
# 0                  1               0         A/5 21171                 7.25
# 1                  1               0          PC 17599              712.833
# ...

# %%
# 1. Selecione somente os passageiros da classe `1`.

df[df['Classe'] == 1]
# Out:
#      Id do passageiro  Sobrevivente  Classe  \
# 1                   2             1       1
# 3                   4             1       1
# 6                   7             0       1
# 11                 12             1       1
# 23                 24             1       1
# ..                ...           ...     ...
# 871               872             1       1
# 872               873             0       1
# 879               880             1       1
# 887               888             1       1
# 889               890             1       1
#
#                                                   Nome       Sexo  Idade  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 6                              McCarthy, Mr. Timothy J  masculino   54.0
# 11                            Bonnell, Miss. Elizabeth   feminino   58.0
# ...

# %%
# 2. Selecione somente os passageiros com idade maior ou igual a `30`.

df[df['Idade'] >= 30]
# Out:
#      Id do passageiro  Sobrevivente  Classe  \
# 1                   2             1       1
# 3                   4             1       1
# 4                   5             0       3
# 6                   7             0       1
# 11                 12             1       1
# ..                ...           ...     ...
# 873               874             0       3
# 879               880             1       1
# 881               882             0       3
# 885               886             0       3
# 890               891             0       3
#
#                                                   Nome       Sexo  Idade  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                             Allen, Mr. William Henry  masculino   35.0
# 6                              McCarthy, Mr. Timothy J  masculino   54.0
# ...

# %%
# 3. Descreva quais os Locais de Embarque mais tiveram sobreviventes.

df[df['Sobrevivente'] == 1]['Local de embarque'].value_counts()
# Out:
# Local de embarque
# S              215
# C               92
# Q               30
# Southampton      2
# Cherbourg        1
# Name: count, dtype: int64

# %%
# 4. Mostre as estatíticas dos passageiros que não sobreviveram.

df[df['Sobrevivente'] == 0].describe()
# Out:
#        Id do passageiro  Sobrevivente      Classe       Idade  \
# count        549.000000         549.0  549.000000  424.000000
# mean         447.016393           0.0    2.531876   30.626179
# std          260.640469           0.0    0.735805   14.172110
# min            1.000000           0.0    1.000000    1.000000
# 25%          211.000000           0.0    2.000000   21.000000
# 50%          455.000000           0.0    3.000000   28.000000
# 75%          675.000000           0.0    3.000000   39.000000
# max          891.000000           0.0    3.000000   74.000000
#
#        Irmaos ou conjuge  Pais ou filhos
# count         549.000000      549.000000
# mean            0.553734        0.329690
# std             1.288399        0.823166
# min             0.000000        0.000000
# 25%             0.000000        0.000000
# 50%             0.000000        0.000000
# 75%             1.000000        0.000000
# max             8.000000        6.000000

# %% [markdown]
# # Filtros AND e OR
# <a name="filtros-and-or"></a>

# %% [markdown]
# Podemos combinar mais de uma condição em um filtro. No pandas:
#
# ```python
# &   representa E
# |   representa OU

# %% [markdown]
# Cada condição deve ficar entre parênteses:
#
# ```
# filtros = (df['turma'] == 'A') & (df['prova_1'] > 7)
# df[filtros]
# ```

# %% [markdown]
# em outro exemplo:
#
# ```
# df[(df['prova_1'] >= 8) | (df['prova_2'] >= 8)]

# %% [markdown]
# ## Descoberta guiada
# *Filtros utilizando AND e OR*

# %% [markdown]
# Usando o DataFrame de notas, responda:
#
# 1. Selecione os alunos da turma `A` que tiraram nota maior que `7` na `prova_1`.
# 2. Selecione os alunos que tiraram nota maior ou igual a `8` na `prova_1` ou na `prova_2`.

# %%
dados = {
    'nome': ['Ana', 'Pedro', 'João', 'Carla', 'Silvio', 'Teresa', 'Claudia', 'Cristiane'],
    'prova_1': [6, 7, 8, 8, 9, 3, 6, 5],
    'prova_2': [7, 8, 5, 7, 10, 8, 7, 7],
    'turma': ['A', 'A', 'B', 'B', 'A', 'B', 'B', 'A']
}

df = pd.DataFrame(dados)
df
# Out:
#         nome  prova_1  prova_2 turma
# 0        Ana        6        7     A
# 1      Pedro        7        8     A
# 2       João        8        5     B
# 3      Carla        8        7     B
# 4     Silvio        9       10     A
# 5     Teresa        3        8     B
# 6    Claudia        6        7     B
# 7  Cristiane        5        7     A

# %%
# 1. Selecione os alunos da turma `A` que tiraram nota maior que `7` na `prova_1`.

df[(df['turma'] == 'A') & (df['prova_1'] > 7)]
# Out:
#      nome  prova_1  prova_2 turma
# 4  Silvio        9       10     A

# %%
# 2. Selecione os alunos que tiraram nota maior ou igual a `8` na `prova_1` ou na `prova_2`.

df[(df['prova_1'] >= 8) | (df['prova_2'] >= 8)]
# Out:
#      nome  prova_1  prova_2 turma
# 1   Pedro        7        8     A
# 2    João        8        5     B
# 3   Carla        8        7     B
# 4  Silvio        9       10     A
# 5  Teresa        3        8     B

# %% [markdown]
# ## Hands on!
# *Filtros utilizando AND e OR*

# %% [markdown]
# Agora, usando o dataset do Titanic, resolva:
#
# 1. Quantos homens sobreviveram e eram das classes `1` ou `2`?
# 2. Quantas pessoas tinham mais de `40` anos e tinham pais/filhos ou irmãos/cônjuges?

# %%
df = pd.read_csv('https://www.harve.com.br/praticas/titanic-pt-BR.csv')
df.head()
# Out:
#    Id do passageiro  Sobrevivente  Classe  \
# 0                 1             0       3
# 1                 2             1       1
# 2                 3             1       3
# 3                 4             1       1
# 4                 5             0       3
#
#                                                 Nome       Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    Irmaos ou conjuge  Pais ou filhos            Ticket Tarifa do passageiro  \
# 0                  1               0         A/5 21171                 7.25
# 1                  1               0          PC 17599              712.833
# ...

# %%
# 1. Quantos homens sobreviveram e eram das classes `1` ou `2`?

len(df[(df['Sexo'] == 'masculino') & (df['Sobrevivente'] == 1) & ((df['Classe'] == 1) | (df['Classe'] == 2))])
# Out:
# 62

# %%
# 2. Quantas pessoas tinham mais de `40` anos e tinham pais/filhos ou irmãos/cônjuges?

len(df[(df['Idade'] > 40) & ((df['Pais ou filhos'] > 0) | (df['Irmaos ou conjuge'] > 0))])
# Out:
# 61

# %% [markdown]
# # Dados faltantes e duplicados
# <a name="dados-faltantes-e-duplicados"></a>

# %% [markdown]
# Antes de analisar os dados, precisamos verificar se existem valores faltantes ou registros duplicados.
#
# Para identificar valores nulos:
#
# ```python
# df.isnull()

# %% [markdown]
# Para contar valores nulos por coluna:
# ```
# df.isnull().sum()
# ```

# %% [markdown]
# Para preencher valores nulos vom um determinado `valor`:
# ```
# df['coluna'].fillna(valor)
# ```

# %% [markdown]
# Para remover linhas com valores nulos:
# ```
# df.dropna()
# ```

# %% [markdown]
# Para remover linhas com valores nulos em um determinado subconjunto use `subset`:
# ```
# df.dropna(subset=['Idade', 'Cabine'])
# ```

# %% [markdown]
# Para verificar valores únicos de uma coluna:
# ```
# df['coluna'].unique()
# ```

# %% [markdown]
# Para verificar linhas duplicadas:
# ```
# df.duplicated()
# ```

# %% [markdown]
# Para remover duplicatas:
# ```
# df.drop_duplicates()
# ```

# %% [markdown]
# ## Descoberta guiada
# *Dados faltantes e duplicados*

# %% [markdown]
# Usando o dataset do Titanic, responda:
#
# 1. Verifique quais colunas possuem valores nulos.
# 2. Quantos valores nulos existem na coluna `Idade`?
# 3. Quais são os valores únicos da coluna `Local de embarque`?
# 4. Verifique se existem linhas duplicadas no DataFrame.

# %%
df = pd.read_csv('https://www.harve.com.br/praticas/titanic-pt-BR.csv')
df.head()
# Out:
#    Id do passageiro  Sobrevivente  Classe  \
# 0                 1             0       3
# 1                 2             1       1
# 2                 3             1       3
# 3                 4             1       1
# 4                 5             0       3
#
#                                                 Nome       Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    Irmaos ou conjuge  Pais ou filhos            Ticket Tarifa do passageiro  \
# 0                  1               0         A/5 21171                 7.25
# 1                  1               0          PC 17599              712.833
# ...

# %%
# 1. Verifique quais colunas possuem valores nulos.

df.isnull().sum()
# Out:
# Id do passageiro          0
# Sobrevivente              0
# Classe                    0
# Nome                      0
# Sexo                      0
# Idade                   177
# Irmaos ou conjuge         0
# Pais ou filhos            0
# Ticket                    0
# Tarifa do passageiro      0
# Cabine                  687
# Local de embarque         2
# dtype: int64

# %%
# 2. Quantos valores nulos existem na coluna `Idade`?

df['Idade'].isnull().sum()
# Out:
# np.int64(177)

# %%
# 3. Quais são os valores únicos da coluna `Local de embarque`?

df['Local de embarque'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', 'S', 'C', 'Q', nan],
#       dtype=object)

# %%
# 4. Verifique se existem linhas duplicadas no DataFrame.

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Hands on!
# *Dados faltantes e duplicados*

# %% [markdown]
# Ainda sobre o dataset do Titanic:
#
# 1. Apague os registros de passageiros sem local de embarque definido.
# 2. Substitua os valores nulos de `Cabine` por `C9999`
# 3. Substitua os valores de `Local de embarque`: `S` por `Southampton`, `C` por `Cherbourg` e `Q` por `Queenstown` e verifique novamente quantas vezes cada valor aparece.

# %%
df = pd.read_csv('https://www.harve.com.br/praticas/titanic-pt-BR.csv')
df.head()
# Out:
#    Id do passageiro  Sobrevivente  Classe  \
# 0                 1             0       3
# 1                 2             1       1
# 2                 3             1       3
# 3                 4             1       1
# 4                 5             0       3
#
#                                                 Nome       Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    Irmaos ou conjuge  Pais ou filhos            Ticket Tarifa do passageiro  \
# 0                  1               0         A/5 21171                 7.25
# 1                  1               0          PC 17599              712.833
# ...

# %%
# 1. Apague os registros de passageiros sem local de embarque definido.

df = df.dropna(subset=['Local de embarque'])
df.describe()
# Out:
#        Id do passageiro  Sobrevivente      Classe       Idade  \
# count        889.000000    889.000000  889.000000  712.000000
# mean         446.000000      0.382452    2.311586   29.642093
# std          256.998173      0.486260    0.834700   14.492933
# min            1.000000      0.000000    1.000000    0.420000
# 25%          224.000000      0.000000    2.000000   20.000000
# 50%          446.000000      0.000000    3.000000   28.000000
# 75%          668.000000      1.000000    3.000000   38.000000
# max          891.000000      1.000000    3.000000   80.000000
#
#        Irmaos ou conjuge  Pais ou filhos
# count         889.000000      889.000000
# mean            0.524184        0.382452
# std             1.103705        0.806761
# min             0.000000        0.000000
# 25%             0.000000        0.000000
# 50%             0.000000        0.000000
# 75%             1.000000        0.000000
# max             8.000000        6.000000

# %%
# 2. Substitua os valores nulos de `Cabine` por `C9999`

df = df['Cabine'].fillna('C9999')
# Out:
# 0      C9999
# 1        C85
# 2      C9999
# 3       C123
# 4      C9999
#        ...
# 886    C9999
# 887      B42
# 888    C9999
# 889     C148
# 890    C9999
# Name: Cabine, Length: 891, dtype: object

# %%
# 3. Substitua os valores de `Local de embarque`:
# `S` por `Southampton`
# `C` por `Cherbourg`
# `Q` por `Queenstown`
#  e verifique novamente quantas vezes cada valor aparece.

df['Local de embarque'] = df['Local de embarque'].replace({'S': 'Southampton', 'C': 'Cherbourg', 'Q': 'Queenstown'})
df['Local de embarque'].value_counts()
# Out:
# Local de embarque
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64
